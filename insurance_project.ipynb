# %% [markdown]
# # Data Science Project - Insurnace

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Names:
# - Beibei Du
# ### Date:
# - 2022/4/25

# %% [markdown]
# ## Abstract
# In recent days, there are a lot of factors affecting the health qualities, such as smoking condtions, age,sex, etc. We want to find out the factors that affect the price of medical charges and see what things can be done to minimize the cost for medical reasons, that reach double-win for both the medical centers, as well as the patients.
#
# With the life style changing of people, we want to find out the  machine learning algorithm with best performance that can predicts the medical bills. Thus I get the dataset from https://github.com/stedy/Machine-Learning-with-R-datasets and I want to use linear regression, correlational studies, and other potential algorithms to predict the accurate bills of insurance.

# %% [markdown]
# ## Background
# Insurance has been a hot area to study and insurance company wants to make money out of all those who purchased the insurance. Especially they want to have enough money from the customers to cover all the bills of the patients. From the perspective of the patients, they want to minimize their bills, otherwise they will get their insurance bills charging more from now on. Thus it is important to know the factors that might increase the medical bills, that leads the financial lost for both the insurance company and the patients themselves.
#
# There are a lot of past researches on how we could predict the insurance prices. Specifically, I found out that they used "Multiple Linear Regression, Generalized Additive Model, Support Vector Machine, Random Forest Regressor, CART, XGBoost, k-Nearest Neighbors, Stochastic Gradient Boosting, and Deep Neural Network" to study the cost of the health insurance costs. (Reference: https://www.researchgate.net/publication/348559741_Predict_Health_Insurance_Cost_by_using_Machine_Learning_and_DNN_Regression_Models)

# %% [markdown]
# ## Problem Statement
# - What are the factors that affect the health insurance the most and what algorithms can predict the costs with the best performance?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data
# - There are 1338 observations and 7 columns in this dataset (https://www.kaggle.com/datasets/mirichoi0218/insurance?resource=download)
# - The following are the columns:
#
# | Column    | Description |
# | ----------- | ----------- |
# |age | age of primary beneficiary|
# |sex |insurance contractor gender, female, male|
# |bmi |Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9|
# |children| Number of children covered by health insurance / Number of dependents|
# |smoker |Smoking|
# |region |the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.|
# |charges |Individual medical costs billed by health insurance|

# %% [markdown]
# ## Proposed Solutions
# As mentioned above, we want to test out the model that best predict the health insurance costs of the patients. We would use linear regression or multivariate regression models to fit out model and use train-test split or k-fold to find the best models. Besides, I will try to use other models rather than simple regression models. I will try to use SVM, random forests, etc to see which one generate the highest accuracy without any overfitting.

# %% [markdown]
# ## Evaluation Metrics
# There are many evaluation metrics that can be used to test out the model. For example, I can use the confusion matrix, f1 score, recall, etc. I will use all of them and explain them with details in the code section below.

# %% [markdown]
# ## Ethics and Privacy
# This is a public dataset without any personal information such as names and specific details. Although the age and region are included, without the names and more personal information, we could not ensure the information belongs to the exact person (it is hard to pin someone with the provided columns).
#
# Thus we won't have too much ethics and privacy issues for now in this question.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
insurance = pd.read_csv('insurance.csv')
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## EDA-exploratory data analysis

# %%
insurance['age'].unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %%
insurance['age'].hist()

# %% [markdown]
# We could see that the peak seems to at at 20-ish. So the data has more younger people than the elderly people.

# %%
insurance['charges'].hist(color = 'pink')

# %% [markdown]
# I like pink so I make the distribution to look pink~

# %%
insurance['sex'].hist(color = 'purple')

# %% [markdown]
# There are more males than females. This histogram looks werid. I need to fix it to look better later.
